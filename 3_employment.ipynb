# %%
## intitial load of DOL employment dataset

'''Current Employment Statistics: Beginning 1990'''

f = open("Current_Employment_Statistics__Beginning_1990.csv","r")
s = f.read()
f.close()
lines = s.split("\n")

# %%
## print column headings

import csv, operator

fn = "Current_Employment_Statistics__Beginning_1990.csv"
f = open(fn, 'r')
## uses csv Dictreader
reader = csv.DictReader(f, skipinitialspace = True)
n = 0
for row in reader:
    ## stops after header row
    if n > 0 :
        break
    ## prints column headings on new row, with | at end, for copying to markdown file
    print(*row, sep = '\n')
    n += 1
# Out:
# Area
# Area Name
# Series
# Title
# Year
# Month
# Current Employment

# %%
## calculate change in employment reported, year over year

import csv, operator

fn = "Current_Employment_Statistics__Beginning_1990.csv"
f = open(fn, 'r')

JurisCount = 0
reader = csv.reader(f)

## create dictionaries for year 1 and year 2

EmpHist = {}
EmpHist2 = {}
# n is counting every row in reader
n = 0
# n2 is counting rows which are y = 2020 and d not null
n2 = 0

## designate the first year, yr 2 is calculated
yr1 = '2020'
yr2 = str(int(yr1) + 1)

for row in reader :
    j = row[1]
    y = row[4]
    m = row[5]
    ## employment
    e = row[6]
    ## type
    t = row[3]
    
    n += 1
    
    ## test
    #print(n)
    #if n > 20 :
    #    break
    
    #print(n, j, m, y, t, e)
    
    ## create a running sum (data is by month, this totals for the year) for the first year - only "total nonfarm" type employment 
    ##    this will be averaged
    ## to compare to sales tax data, translate the years - January and February of year 1 are part of the sales tax year, as are the
    ##   months March through December of the previous year
    if y == yr1 and m <= '2' and t == 'Total Nonfarm' and e != '' :
        ## test
        #print(n, j, m, y, t, e)
        if j in EmpHist.keys() :
            employ = int(EmpHist[j])
            add = int(e)
            EmpHist[j] = employ + add
        else:
            EmpHist[j] = int(e)
    if y == str(int(yr1)-1) and m > '2' and t == 'Total Nonfarm' and e != '' :
        ## test
        #print(n, j, m, y, t, e)
        if j in EmpHist.keys() :
            employ = int(EmpHist[j])
            add = int(e)
            EmpHist[j] = employ + add
        else:
            EmpHist[j] = int(e)
    
    ## create a running sum for the second year - only "total nonfarm" type employment, this will be averaged
    if y == yr2 and m <= '2' and t == 'Total Nonfarm' and e != '' :
        ## test
        #print(n, j, m, y, t, e)
        if j in EmpHist2.keys() :
            employ = int(EmpHist2[j])
            add = int(e)
            EmpHist2[j] = employ + add
        else:
            EmpHist2[j] = int(e)
    if y == str(int(yr2)-1) and m > '2' and t == 'Total Nonfarm' and e != '' :
        ## test
        #print(n, j, m, y, t, e)
        if j in EmpHist2.keys() :
            employ = int(EmpHist2[j])
            add = int(e)
            EmpHist2[j] = employ + add
        else:
            EmpHist2[j] = int(e)
            
## average the total employment numbers for the year to a monthly rate
##  each month is not additional jobs, so to compare to sales tax numbers for the entire year
##  decided to average the jobs for the same time period
for key in EmpHist.keys() :
    #print(key, EmpHist[key])
    TotalEmp = EmpHist[key]
    EmpHist[key] = TotalEmp/12
    #print(TotalEmp, key, EmpHist[key])
for key1 in EmpHist2.keys() :
    #print(key1, EmpHist2[key1])
    TotalEmp2 = EmpHist2[key1]
    EmpHist2[key1] = TotalEmp2/12
    #print(TotalEmp2, key1, EmpHist2[key1])
        
#print("Year 1:", yr1, EmpHist)
#print("Year 2:", yr2, EmpHist2)


print("Average employment reported by year, by jurisdiction, Total Nonfarm type employment")

## create lists to store any jurisdictions reported in 1 year but not the other
Yr1_only = []
Yr2_only = []
for key1 in EmpHist.keys():
    if key1 not in EmpHist2.keys():
        Yr1_only.append(key1)
for key2 in EmpHist2.keys():
    if key2 not in EmpHist2.keys() :
        Yr2_only.append(key2)
print("Jurisdictions in Yr1 only:", Yr1_only)
print("Jurisdictions in Yr2 only:", Yr2_only)

## create a dictionary for the employment change, to compare with the sales tax data
Emp_change = {}

## print the average employment by year, change between years, and percentage change
print(f"{'Jurisdiction':40}{yr1:>20}{yr2:>20}{'Change':>20}{'Percent change':>20}")
for key, value in EmpHist.items() :
    change = EmpHist2[key] - EmpHist[key]
    perc_change = change/EmpHist[key]
    print(f"{key:40}{value:>20,.0f}{EmpHist2[key]:>20,.0f}{change:>20,.0f}{perc_change:>20.2%}")
    Emp_change[key] = perc_change
#print(Emp_change)
# Out:
# Average employment reported by year, by jurisdiction, Total Nonfarm type employment
# Jurisdictions in Yr1 only: []
# Jurisdictions in Yr2 only: []
# Jurisdiction                                            2020                2021              Change      Percent change
# Statewide                                          9,529,717           6,391,408          -3,138,308             -32.93%
# Allegany County                                       14,742              10,208              -4,533             -30.75%
# Cattaraugus County                                    29,767              19,875              -9,892             -33.23%
# Cayuga County                                         24,958              17,075              -7,883             -31.59%
# Chautauqua County                                     49,342              33,150             -16,192             -32.82%
# Chenango County                                       17,333              12,225              -5,108             -29.47%
# Clinton County                                        34,267              23,225             -11,042             -32.22%
# Columbia County                                       21,175              14,417              -6,758             -31.92%
# Cortland County                                       18,992              13,025              -5,967             -31.42%
# Delaware County                                       15,092              10,458              -4,633             -30.70%
# Essex County                                          14,458               9,725              -4,733             -32.74%
# Franklin County                                       18,308              12,525              -5,783             -31.59%
# Fulton County                                         16,833              11,667              -5,167             -30.69%
# Genesee County                                        22,467              15,233              -7,233             -32.20%
# Greene County                                         14,533              10,108              -4,425             -30.45%
# Hamilton County                                        1,825               1,258                -567             -31.05%
# Lewis County                                           6,342               4,433              -1,908             -30.09%
# Montgomery County                                     19,017              12,900              -6,117             -32.16%
# Otsego County                                         24,858              16,475              -8,383             -33.72%
# St. Lawrence County                                   38,208              26,550             -11,658             -30.51%
# Schuyler County                                        4,858               3,333              -1,525             -31.39%
# Seneca County                                         12,067               7,825              -4,242             -35.15%
# Steuben County                                        37,400              25,608             -11,792             -31.53%
# Sullivan County                                       28,700              19,192              -9,508             -33.13%
# Wyoming County                                        12,908               9,083              -3,825             -29.63%
# Albany-Schenectady-Troy Metro Area                   463,883             320,667            -143,217             -30.87%
# Binghamton Metro Area                                100,458              68,267             -32,192             -32.04%
# Buffalo-Niagara Falls Metro Area                     552,242             371,133            -181,108             -32.80%
# Dutchess-Putnam Metropolitan Division                145,233              98,458             -46,775             -32.21%
# Elmira Metro Area                                     36,325              24,983             -11,342             -31.22%
# Glens Falls Metro Area                                53,975              36,617             -17,358             -32.16%
# Ithaca Metro Area                                     61,783              42,550             -19,233             -31.13%
# Kingston Metro Area                                   60,642              40,742             -19,900             -32.82%
# Nassau-Suffolk Metropolitan Division               1,319,308             881,208            -438,100             -33.21%
# Rochester Metro Area                                 527,208             360,208            -167,000             -31.68%
# Syracuse Metro Area                                  313,958             215,283             -98,675             -31.43%
# Utica-Rome Metro Area                                125,767              86,183             -39,583             -31.47%
# Watertown-Fort Drum Metro Area                        40,817              27,917             -12,900             -31.60%
# New York City                                      4,508,717           2,999,850          -1,508,867             -33.47%
# Orange-Rockland-Westchester Metro Area               717,550             480,792            -236,758             -33.00%

# %%
## initial open the st_change file created from the sales tax reported dataset

f_st = open("st_change.csv","r")
s_st = f_st.read()
f_st.close()
lines = s_st.split("\n")

# %%
## sales tax data, calculated by the same geographical areas as the DOL data
## important to check the results to the results from the sales tax dataset analysis - this can be done by
##    looking at some of the "minor counties", such as Cayuga, Fulton, and Montgomery

import csv, operator

f_st_change = "st_change.csv"
f_st_ch = open(f_st_change, 'r')

f_dol = "DOL_geog_areas.csv"
f_areas = open(f_dol, 'r')

JurisCount = 0
reader_stc = csv.reader(f_st_ch)
reader_dol = csv.reader(f_areas)
## create a dictionary for storing the data
ST_changeHist = {}

n_stc = 0

for row_c in reader_stc:
    reader_dol = csv.reader(open(f_dol,'r'))
    if n_stc > 0 :
        y1 = float(row_c[1])
        y2 = float(row_c[2])
        change = y2 - y1
        base = y1
        area = row_c[0]
        #print(n_stc, area, y1, y2, change, base)
        
        ## find the applicable DOL geographical area for the sales tax jurisdiction
        for row_dol in reader_dol :
            if area == row_dol[1].upper() :
                region = row_dol[3]
                break
                
        ## calculate the change and percentage change, from year 1 to year 2, and store in dictionary
        if region in ST_changeHist.keys () :
            adj_change = int(ST_changeHist[region]['change'])
            add = int(change)
            ST_changeHist[region]['change'] = adj_change + add

            base_change = int(ST_changeHist[region]['base'])
            add_base = int(base)
            ST_changeHist[region]['base'] = base_change + add_base
        else :
            ST_changeHist[region] = {}
            ST_changeHist[region]['change'] = change
            ST_changeHist[region]['base'] = base
        #print(n_stc, area, region, change, base)
    n_stc += 1

#print(ST_changeHist)

## create a dictionary for storing the calculations for comparison to the DOL data
p_change_hist = {}

## print the results and store them in the dictionary p_change_hist
print("Change in sales tax from year 1, by DOL geographical area")
print(f"{'Area':50}{'Change':>20}{'Year 1':>20}{'Percent change':>20}")
for key in ST_changeHist :
    p_change = ST_changeHist[key]['change']/ST_changeHist[key]['base']
    p_change_hist[key] = p_change
    ch = ST_changeHist[key]['change']
    bs = ST_changeHist[key]['base']
    print(f"{key:50}{ch:>20,.2f}{bs:>20,.2f}{p_change:>20,.2%}")
    
#print(p_change_hist)
# Out:
# Change in sales tax from year 1, by DOL geographical area
# Area                                                            Change              Year 1      Percent change
# Rochester Metro Area                                   -732,379,454.00    1,841,932,049.00             -39.76%
# Albany-Schenectady-Troy Metro Area                      -13,716,538.00       55,154,540.00             -24.87%
# Allegany County                                            -222,476.63        1,395,069.89             -15.95%
# Binghamton Metro Area                                    -2,165,148.00       13,133,530.00             -16.49%
# Cattaraugus County                                         -490,824.52        3,569,230.44             -13.75%
# Cayuga County                                              -641,860.52        3,430,970.04             -18.71%
# Chautauqua County                                          -768,852.72        6,717,881.04             -11.44%
# Elmira Metro Area                                          -849,205.64        5,261,823.88             -16.14%
# Chenango County                                            -180,930.36        1,343,271.92             -13.47%
# Clinton County                                             -872,818.32        4,636,542.88             -18.82%
# Columbia County                                            -582,298.92        3,175,313.88             -18.34%
# Cortland County                                            -398,672.36        2,345,789.16             -17.00%
# Delaware County                                            -144,786.52        1,306,656.08             -11.08%
# Dutchess-Putnam Metropolitan Division                    -4,166,310.00       21,896,068.00             -19.03%
# Buffalo-Niagara Falls Metro Area                        -19,950,021.00       94,196,959.00             -21.18%
# Essex County                                               -572,613.92        2,616,156.76             -21.89%
# Franklin County                                            -167,726.08        1,498,528.88             -11.19%
# Fulton County                                              -122,474.88        2,264,359.24              -5.41%
# Genesee County                                             -558,207.40        3,543,316.68             -15.75%
# Greene County                                              -397,526.92        2,599,582.08             -15.29%
# Hamilton County                                             -84,037.64          289,841.16             -28.99%
# Utica-Rome Metro Area                                    -2,566,420.00       15,022,190.00             -17.08%
# Watertown-Fort Drum Metro Area                             -826,694.84        7,348,352.84             -11.25%
# Lewis County                                               -140,335.96          839,431.52             -16.72%
# Syracuse Metro Area                                      -8,960,267.00       38,878,210.00             -23.05%
# Montgomery County                                          -261,015.72        2,103,963.52             -12.41%
# Nassau-Suffolk Metropolitan Division                    -41,489,394.00      249,950,568.00             -16.60%
# New York City                                          -585,021,025.80    1,026,295,576.29             -57.00%
# Orange-Rockland-Westchester Metro Area                  -26,020,104.00      111,686,821.00             -23.30%
# Otsego County                                            -1,094,278.76        3,566,457.84             -30.68%
# Schuyler County                                            -150,166.44          895,099.72             -16.78%
# Seneca County                                              -289,823.56        1,600,167.64             -18.11%
# St. Lawrence County                                        -544,627.48        4,021,327.04             -13.54%
# Steuben County                                             -856,259.04        4,151,313.00             -20.63%
# Sullivan County                                            -351,435.04        2,784,410.28             -12.62%
# Ithaca Metro Area                                        -2,322,792.56        6,317,079.60             -36.77%
# Kingston Metro Area                                      -2,191,973.36       11,313,290.76             -19.38%
# Glens Falls Metro Area                                   -1,181,865.00        7,105,768.00             -16.63%
# Wyoming County                                             -165,709.80        1,475,010.36             -11.23%

# %%
## compare the sales tax change to the employment data change

## create lists for any jurisdictions which were in one dictionary, but not the other
Emp_only = []
ST_only = []
## compare dictionaries and store any unmatched
for keyE in Emp_change.keys():
    if keyE not in p_change_hist.keys():
        Emp_only.append(keyE)
for keyST in p_change_hist.keys():
    if keyST not in Emp_change.keys() :
        ST_only.append(keyST)
        
print("Change in employment numbers (DOL) to change in sales tax, year over year")
print("Regions in Employment data only:", Emp_only)
print("Regions in ST data only:", ST_only)

## print the DOL change, ST change, and difference
print(f"{'Region':50}{'Employment change':>20}{'ST change':>20}{'Difference':>20}")
for key, value in Emp_change.items() :
    if key in p_change_hist :
        differ = p_change_hist[key] - Emp_change[key]
        print(f"{key:50}{value:>20,.2%}{p_change_hist[key]:>20,.2%}{differ:>20,.2%}")
# Out:
# Change in employment numbers (DOL) to change in sales tax, year over year
# Regions in Employment data only: ['Statewide']
# Regions in ST data only: []
# Region                                               Employment change           ST change          Difference
# Allegany County                                                -30.75%             -15.95%              14.80%
# Cattaraugus County                                             -33.23%             -13.75%              19.48%
# Cayuga County                                                  -31.59%             -18.71%              12.88%
# Chautauqua County                                              -32.82%             -11.44%              21.37%
# Chenango County                                                -29.47%             -13.47%              16.00%
# Clinton County                                                 -32.22%             -18.82%              13.40%
# Columbia County                                                -31.92%             -18.34%              13.58%
# Cortland County                                                -31.42%             -17.00%              14.42%
# Delaware County                                                -30.70%             -11.08%              19.62%
# Essex County                                                   -32.74%             -21.89%              10.85%
# Franklin County                                                -31.59%             -11.19%              20.40%
# Fulton County                                                  -30.69%              -5.41%              25.28%
# Genesee County                                                 -32.20%             -15.75%              16.44%
# Greene County                                                  -30.45%             -15.29%              15.16%
# Hamilton County                                                -31.05%             -28.99%               2.06%
# Lewis County                                                   -30.09%             -16.72%              13.37%
# Montgomery County                                              -32.16%             -12.41%              19.76%
# Otsego County                                                  -33.72%             -30.68%               3.04%
# St. Lawrence County                                            -30.51%             -13.54%              16.97%
# Schuyler County                                                -31.39%             -16.78%              14.61%
# Seneca County                                                  -35.15%             -18.11%              17.04%
# Steuben County                                                 -31.53%             -20.63%              10.90%
# Sullivan County                                                -33.13%             -12.62%              20.51%
# Wyoming County                                                 -29.63%             -11.23%              18.40%
# Albany-Schenectady-Troy Metro Area                             -30.87%             -24.87%               6.00%
# Binghamton Metro Area                                          -32.04%             -16.49%              15.56%
# Buffalo-Niagara Falls Metro Area                               -32.80%             -21.18%              11.62%
# Dutchess-Putnam Metropolitan Division                          -32.21%             -19.03%              13.18%
# Elmira Metro Area                                              -31.22%             -16.14%              15.08%
# Glens Falls Metro Area                                         -32.16%             -16.63%              15.53%
# Ithaca Metro Area                                              -31.13%             -36.77%              -5.64%
# Kingston Metro Area                                            -32.82%             -19.38%              13.44%
# Nassau-Suffolk Metropolitan Division                           -33.21%             -16.60%              16.61%
# Rochester Metro Area                                           -31.68%             -39.76%              -8.09%
# Syracuse Metro Area                                            -31.43%             -23.05%               8.38%
# Utica-Rome Metro Area                                          -31.47%             -17.08%              14.39%
# Watertown-Fort Drum Metro Area                                 -31.60%             -11.25%              20.35%
# New York City                                                  -33.47%             -57.00%             -23.54%
# Orange-Rockland-Westchester Metro Area                         -33.00%             -23.30%               9.70%

# %%
## testing code

import csv, operator

f_st_change = "st_change.csv"
f_st_ch = open(f_st_change, 'r')

f_dol = "DOL_geog_areas.csv"
f_areas = open(f_dol, 'r')

JurisCount = 0
reader_stc = csv.reader(f_st_ch)
reader_dol = csv.reader(f_areas)
ST_changeHist = {}

n_stc = 0

for row_c in reader_stc:
#    print(n_stc, type(row_c[0]), type(row_c[1]), type(row_c[2]))
    print(n, *row_c)
    n_stc += 1
# Out:
# 412551 Jurisdiction Yr1 Yr2
# 412551 NY STATE 1658698885.96 993338934.2
# 412551 MCTD 120390078.44 65064198.36
# 412551 ALBANY 25715013.32 18102370.12
# 412551 ALLEGANY 1395069.89 1172593.26
# 412551 BROOME 11776551.44 9800790.24
# 412551 CATTARAUGUS 3569230.44 3078405.92
# 412551 CAYUGA 3430970.04 2789109.52
# 412551 CHAUTAUQUA 6717881.04 5949028.32
# 412551 CHEMUNG 5261823.88 4412618.24
# 412551 CHENANGO 1343271.92 1162341.56
# 412551 CLINTON 4636542.88 3763724.56
# 412551 COLUMBIA 3175313.88 2593014.96
# 412551 CORTLAND 2345789.16 1947116.8
# 412551 DELAWARE 1306656.08 1161869.56
# 412551 DUTCHESS 17632962.22 14135647.28
# 412551 ERIE 81970206.6 64058341.49
# 412551 ESSEX 2616156.76 2043542.84
# 412551 FRANKLIN 1498528.88 1330802.8
# 412551 FULTON 2264359.24 2141884.36
# 412551 GENESEE 3543316.68 2985109.28
# 412551 GREENE 2599582.08 2202055.16
# 412551 HAMILTON 289841.16 205803.52
# 412551 HERKIMER 2818725.21 2381964.39
# 412551 JEFFERSON 7348352.84 6521658.0
# 412551 LEWIS 839431.52 699095.56
# 412551 LIVINGSTON 2952831.6 2566909.2
# 412551 MADISON 2659893.76 2218473.04
# 412551 MONROE 47537147.24 38193309.64
# 412551 MONTGOMERY 2103963.52 1842947.8
# 412551 NASSAU 120874237.63 98536249.45
# 412551 NIAGARA 12226753.56 10188597.44
# 412551 NY CITY 1026295576.29 441274550.49
# 412551 ONEIDA 12203465.36 10073804.6
# 412551 ONONDAGA 33089486.48 24911877.24
# 412551 ONTARIO 7473315.71 5885918.75
# 412551 ORANGE 21910208.32 18109393.27
# 412551 ORLEANS 1186546.44 1176866.8
# 412551 OSWEGO 3128831.48 2787593.04
# 412551 OTSEGO 3566457.84 2472179.08
# 412551 PUTNAM 4263106.76 3594109.92
# 412551 RENSSELAER 7819678.92 6154089.8
# 412551 ROCKLAND 17254301.48 12981793.6
# 412551 SARATOGA 12950184.21 9855636.09
# 412551 SCHENECTADY 7682311.08 6468171.6
# 412551 SCHOHARIE 987354.48 857735.44
# 412551 SCHUYLER 895099.72 744933.28
# 412551 SENECA 1600167.64 1310344.08
# 412551 ST LAWRENCE 4021327.04 3476699.56
# 412551 STEUBEN 4151313.0 3295053.96
# 412551 SUFFOLK 129076331.42 109924925.32
# 412551 SULLIVAN 2784410.28 2432975.24
# 412551 TIOGA 1356979.16 1167591.92
# 412551 TOMPKINS 6317079.6 3994287.04
# 412551 ULSTER 11313290.76 9121317.4
# 412551 WARREN 6103127.52 5016306.27
# 412551 WASHINGTON 1002641.46 907596.9
# 412551 WAYNE 2914770.56 2701585.24
# 412551 WESTCHESTER 72522312.52 54575530.28
# 412551 WYOMING 1475010.36 1309300.56
# 412551 YATES 778477.28 624873.0

# %%
'''Current Employment Statistics: Beginning 1990'''

f = open("Current_Employment_Statistics__Beginning_1990.csv","r")
s = f.read()
f.close()
lines = s.split("\n")

# %%
import csv, operator

fn = "Current_Employment_Statistics__Beginning_1990.csv"
f = open(fn, 'r')
## uses csv Dictreader
reader = csv.DictReader(f, skipinitialspace = True)
n = 0
for row in reader:
    ## stops after header row
    if n > 0 :
        break
    ## prints column headings on new row, with | at end, for copying to markdown file
    print(*row, sep = '\n')
    n += 1
# Out:
# Area
# Area Name
# Series
# Title
# Year
# Month
# Current Employment

# %%
import csv, operator

fn = "Current_Employment_Statistics__Beginning_1990.csv"
f = open(fn, 'r')

JurisCount = 0
reader = csv.reader(f)
EmpHist = {}
EmpHist2 = {}
# n is counting every row in reader
n = 0
# n2 is counting rows which are y = 2020 and d not null
n2 = 0

yr1 = '2020'
yr2 = str(int(yr1) + 1)

for row in reader :
    j = row[1]
    y = row[4]
    m = row[5]
    ## employment
    e = row[6]
    ## type
    t = row[3]
    
    n += 1
    
    ## test
    #print(n)
    #if n > 20 :
    #    break
    
    #print(n, j, m, y, t, e)
    
    if y == yr1 and m <= '2' and t == 'Total Nonfarm' and e != '' :
        ## test
        #print(n, j, m, y, t, e)
        if j in EmpHist.keys() :
            employ = int(EmpHist[j])
            add = int(e)
            EmpHist[j] = employ + add
        else:
            EmpHist[j] = int(e)
    if y == str(int(yr1)-1) and m > '2' and t == 'Total Nonfarm' and e != '' :
        ## test
        #print(n, j, m, y, t, e)
        if j in EmpHist.keys() :
            employ = int(EmpHist[j])
            add = int(e)
            EmpHist[j] = employ + add
        else:
            EmpHist[j] = int(e)
    
    if y == yr2 and m <= '2' and t == 'Total Nonfarm' and e != '' :
        ## test
        #print(n, j, m, y, t, e)
        if j in EmpHist2.keys() :
            employ = int(EmpHist2[j])
            add = int(e)
            EmpHist2[j] = employ + add
        else:
            EmpHist2[j] = int(e)
    if y == str(int(yr2)-1) and m > '2' and t == 'Total Nonfarm' and e != '' :
        ## test
        #print(n, j, m, y, t, e)
        if j in EmpHist2.keys() :
            employ = int(EmpHist2[j])
            add = int(e)
            EmpHist2[j] = employ + add
        else:
            EmpHist2[j] = int(e)
            
for key in EmpHist.keys() :
    #print(key, EmpHist[key])
    TotalEmp = EmpHist[key]
    EmpHist[key] = TotalEmp/12
    #print(TotalEmp, key, EmpHist[key])
for key1 in EmpHist2.keys() :
    #print(key1, EmpHist2[key1])
    TotalEmp2 = EmpHist2[key1]
    EmpHist2[key1] = TotalEmp2/12
    #print(TotalEmp2, key1, EmpHist2[key1])
        
#print("Year 1:", yr1, EmpHist)
#print("Year 2:", yr2, EmpHist2)

Yr1_only = []
Yr2_only = []
for key1 in EmpHist.keys():
    if key1 not in EmpHist2.keys():
        Yr1_only.append(key1)
for key2 in EmpHist2.keys():
    if key2 not in EmpHist2.keys() :
        Yr2_only.append(key2)
print("Jurisdictions in Yr1 only:", Yr1_only)
print("Jurisdictions in Yr2 only:", Yr2_only)

Emp_change = {}

print(f"{'Jurisdiction':40}{yr1:>20}{yr2:>20}{'Change':>20}{'Percent change':>20}")
for key, value in EmpHist.items() :
    change = EmpHist2[key] - EmpHist[key]
    perc_change = change/EmpHist[key]
    print(f"{key:40}{value:>20,.0f}{EmpHist2[key]:>20,.0f}{change:>20,.0f}{perc_change:>20.2%}")
    Emp_change[key] = perc_change
#print(Emp_change)
# Out:
# Jurisdictions in Yr1 only: []
# Jurisdictions in Yr2 only: []
# Jurisdiction                                            2020                2021              Change      Percent change
# Statewide                                          9,529,717           6,391,408          -3,138,308             -32.93%
# Allegany County                                       14,742              10,208              -4,533             -30.75%
# Cattaraugus County                                    29,767              19,875              -9,892             -33.23%
# Cayuga County                                         24,958              17,075              -7,883             -31.59%
# Chautauqua County                                     49,342              33,150             -16,192             -32.82%
# Chenango County                                       17,333              12,225              -5,108             -29.47%
# Clinton County                                        34,267              23,225             -11,042             -32.22%
# Columbia County                                       21,175              14,417              -6,758             -31.92%
# Cortland County                                       18,992              13,025              -5,967             -31.42%
# Delaware County                                       15,092              10,458              -4,633             -30.70%
# Essex County                                          14,458               9,725              -4,733             -32.74%
# Franklin County                                       18,308              12,525              -5,783             -31.59%
# Fulton County                                         16,833              11,667              -5,167             -30.69%
# Genesee County                                        22,467              15,233              -7,233             -32.20%
# Greene County                                         14,533              10,108              -4,425             -30.45%
# Hamilton County                                        1,825               1,258                -567             -31.05%
# Lewis County                                           6,342               4,433              -1,908             -30.09%
# Montgomery County                                     19,017              12,900              -6,117             -32.16%
# Otsego County                                         24,858              16,475              -8,383             -33.72%
# St. Lawrence County                                   38,208              26,550             -11,658             -30.51%
# Schuyler County                                        4,858               3,333              -1,525             -31.39%
# Seneca County                                         12,067               7,825              -4,242             -35.15%
# Steuben County                                        37,400              25,608             -11,792             -31.53%
# Sullivan County                                       28,700              19,192              -9,508             -33.13%
# Wyoming County                                        12,908               9,083              -3,825             -29.63%
# Albany-Schenectady-Troy Metro Area                   463,883             320,667            -143,217             -30.87%
# Binghamton Metro Area                                100,458              68,267             -32,192             -32.04%
# Buffalo-Niagara Falls Metro Area                     552,242             371,133            -181,108             -32.80%
# Dutchess-Putnam Metropolitan Division                145,233              98,458             -46,775             -32.21%
# Elmira Metro Area                                     36,325              24,983             -11,342             -31.22%
# Glens Falls Metro Area                                53,975              36,617             -17,358             -32.16%
# Ithaca Metro Area                                     61,783              42,550             -19,233             -31.13%
# Kingston Metro Area                                   60,642              40,742             -19,900             -32.82%
# Nassau-Suffolk Metropolitan Division               1,319,308             881,208            -438,100             -33.21%
# Rochester Metro Area                                 527,208             360,208            -167,000             -31.68%
# Syracuse Metro Area                                  313,958             215,283             -98,675             -31.43%
# Utica-Rome Metro Area                                125,767              86,183             -39,583             -31.47%
# Watertown-Fort Drum Metro Area                        40,817              27,917             -12,900             -31.60%
# New York City                                      4,508,717           2,999,850          -1,508,867             -33.47%
# Orange-Rockland-Westchester Metro Area               717,550             480,792            -236,758             -33.00%

# %%
f_st = open("st_change.csv","r")
s_st = f_st.read()
f_st.close()
lines = s_st.split("\n")

# %%
import csv, operator

f_st_change = "st_change.csv"
f_st_ch = open(f_st_change, 'r')

f_dol = "DOL_geog_areas.csv"
f_areas = open(f_dol, 'r')

JurisCount = 0
reader_stc = csv.reader(f_st_ch)
reader_dol = csv.reader(f_areas)
ST_changeHist = {}

n_stc = 0

for row_c in reader_stc:
    reader_dol = csv.reader(open(f_dol,'r'))
    if n_stc > 0 :
        y1 = float(row_c[1])
        y2 = float(row_c[2])
        change = y2 - y1
        base = y1
        area = row_c[0]
        #print(n_stc, area, change, base)
        for row_dol in reader_dol :
            if area == row_dol[1].upper() :
                region = row_dol[3]
                break
            if region in ST_changeHist.keys () :
                adj_change = int(ST_changeHist[region]['change'])
                add = int(change)
                ST_changeHist[region]['change'] = adj_change + add

                base_change = int(ST_changeHist[region]['base'])
                add_base = int(base)
                ST_changeHist[region]['base'] = base_change + add_base
            else :
                ST_changeHist[region] = {}
                #new_keys = ['change', 'base']
                #new_values = [change, base]
                #ST_changeHist[region] = dict(zip(ikeys, ivalues))
                ST_changeHist[region]['change'] = change
                ST_changeHist[region]['base'] = base
        #print(n_stc, area, region, change, base)
    n_stc += 1

#print(ST_changeHist)

p_change_hist = {}

print(f"{'Area':50}{'Change':>20}{'Year 1':>20}{'Percent change':>20}")
for key in ST_changeHist :
    p_change = ST_changeHist[key]['change']/ST_changeHist[key]['base']
    p_change_hist[key] = p_change
    ch = ST_changeHist[key]['change']
    bs = ST_changeHist[key]['base']
    print(f"{key:50}{ch:>20,.2f}{bs:>20,.2f}{p_change:>20,.2%}")
    
print(p_change_hist)
# Out:
# Area                                                            Change              Year 1      Percent change
# Rochester Metro Area                                -67,134,237,230.00  120,222,898,489.00             -55.84%
# Albany-Schenectady-Troy Metro Area                     -504,542,636.00    1,203,499,946.00             -41.92%
# Allegany County                                         -18,247,672.00       47,101,236.00             -38.74%
# Binghamton Metro Area                                  -187,410,575.00      365,260,435.00             -51.31%
# Cattaraugus County                                       -7,953,810.00       20,579,700.00             -38.65%
# Cayuga County                                           -15,771,749.00       47,015,857.00             -33.55%
# Chautauqua County                                       -16,122,680.00       42,094,584.00             -38.30%
# Elmira Metro Area                                        -4,267,188.00       12,089,439.00             -35.30%
# Chenango County                                         -18,236,550.00       46,351,670.00             -39.34%
# Clinton County                                          -13,687,014.00       34,946,626.00             -39.17%
# Columbia County                                         -10,830,516.00       28,118,268.00             -38.52%
# Cortland County                                          -5,482,204.00       16,986,528.00             -32.27%
# Delaware County                                         -99,720,250.00      246,835,428.00             -40.40%
# Dutchess-Putnam Metropolitan Division                  -644,802,174.00    1,557,077,550.00             -41.41%
# Buffalo-Niagara Falls Metro Area                    -45,216,658,587.00   65,705,520,342.00             -68.82%
# Essex County                                             -8,238,897.00       25,474,976.00             -32.34%
# Franklin County                                         -11,771,370.00       40,589,424.00             -29.00%
# Fulton County                                           -24,733,402.00       67,323,004.00             -36.74%
# Genesee County                                          -19,914,200.00       51,991,640.00             -38.30%
# Greene County                                            -2,451,267.00        6,086,661.00             -40.27%
# Hamilton County                                         -22,138,754.00       61,967,818.00             -35.73%
# Utica-Rome Metro Area                                  -552,250,732.00    1,292,653,881.00             -42.72%
# Watertown-Fort Drum Metro Area                           -8,851,125.00       20,985,775.00             -42.18%
# Lewis County                                            -25,781,392.00       76,773,450.00             -33.58%
# Syracuse Metro Area                                    -709,990,555.00    1,728,852,254.00             -41.07%
# Montgomery County                                    -1,495,934,490.00    3,621,550,020.00             -41.31%
# Nassau-Suffolk Metropolitan Division                   -198,148,745.00      538,423,970.00             -36.80%
# New York City                                          -153,043,110.00      401,892,348.00             -38.08%
# Orange-Rockland-Westchester Metro Area                 -287,006,414.00      716,644,657.00             -40.05%
# Otsego County                                           -62,601,760.00      170,487,400.00             -36.72%
# Schuyler County                                         -29,474,921.00       78,372,413.00             -37.61%
# Seneca County                                           -70,625,800.00      201,065,900.00             -35.13%
# St. Lawrence County                                     -85,589,373.00      211,707,171.00             -40.43%
# Steuben County                                       -2,408,415,516.00    6,708,035,776.00             -35.90%
# Sullivan County                                         -25,765,722.00       73,741,590.00             -34.94%
# Ithaca Metro Area                                      -248,586,912.00      631,168,104.00             -39.39%
# Kingston Metro Area                                    -118,901,544.00      347,878,239.00             -34.18%
# Glens Falls Metro Area                                  -68,960,855.00      230,058,864.00             -29.98%
# Wyoming County                                          -16,933,192.00       48,265,574.00             -35.08%
# {'Rochester Metro Area': -0.5584147285896834, 'Albany-Schenectady-Troy Metro Area': -0.4192294629317748, 'Allegany County': -0.387413867440761, 'Binghamton Metro Area': -0.5130875316402664, 'Cattaraugus County': -0.3864881412265485, 'Cayuga County': -0.3354559505317536, 'Chautauqua County': -0.38301079302743557, 'Elmira Metro Area': -0.3529682394691764, 'Chenango County': -0.3934388987494949, 'Clinton County': -0.3916548052450042, 'Columbia County': -0.38517720935016336, 'Cortland County': -0.32273834888448066, 'Delaware County': -0.40399488358697033, 'Dutchess-Putnam Metropolitan Division': -0.4141105072126947, 'Buffalo-Niagara Falls Metro Area': -0.6881713796899467, 'Essex County': -0.3234113743620406, 'Franklin County': -0.2900107673368314, 'Fulton County': -0.36738411138041316, 'Genesee County': -0.38302696356568094, 'Greene County': -0.402727702429953, 'Hamilton County': -0.3572621195085488, 'Utica-Rome Metro Area': -0.4272224298532083, 'Watertown-Fort Drum Metro Area': -0.4217678403585286, 'Lewis County': -0.33581129934892856, 'Syracuse Metro Area': -0.41067161948472664, 'Montgomery County': -0.41306470481940216, 'Nassau-Suffolk Metropolitan Division': -0.3680162029190491, 'New York City': -0.3808062302295937, 'Orange-Rockland-Westchester Metro Area': -0.4004863654484764, 'Otsego County': -0.36719288346235557, 'Schuyler County': -0.37608796095125974, 'Seneca County': -0.3512569759466921, 'St. Lawrence County': -0.40428187952121847, 'Steuben County': -0.35903438747551486, 'Sullivan County': -0.34940556611269163, 'Ithaca Metro Area': -0.3938521456084226, 'Kingston Metro Area': -0.3417906918863068, 'Glens Falls Metro Area': -0.299753088409582, 'Wyoming County': -0.3508337433218965}

# %%
Emp_only = []
ST_only = []
for keyE in Emp_change.keys():
    if keyE not in p_change_hist.keys():
        Emp_only.append(keyE)
for keyST in p_change_hist.keys():
    if keyST not in Emp_change.keys() :
        ST_only.append(keyST)
print("Regions in Employment data only:", Emp_only)
print("Regions in ST data only:", ST_only)

print(f"{'Region':50}{'Employment change':>20}{'ST change':>20}{'Difference':>20}")
for key, value in Emp_change.items() :
    if key in p_change_hist :
        differ = p_change_hist[key] - Emp_change[key]
        print(f"{key:50}{value:>20,.2%}{p_change_hist[key]:>20,.2%}{differ:>20,.2%}")
# Out:
# Regions in Employment data only: ['Statewide']
# Regions in ST data only: []
# Region                                               Employment change           ST change          Difference
# Allegany County                                                -30.75%             -38.74%              -7.99%
# Cattaraugus County                                             -33.23%             -38.65%              -5.42%
# Cayuga County                                                  -31.59%             -33.55%              -1.96%
# Chautauqua County                                              -32.82%             -38.30%              -5.49%
# Chenango County                                                -29.47%             -39.34%              -9.87%
# Clinton County                                                 -32.22%             -39.17%              -6.94%
# Columbia County                                                -31.92%             -38.52%              -6.60%
# Cortland County                                                -31.42%             -32.27%              -0.86%
# Delaware County                                                -30.70%             -40.40%              -9.70%
# Essex County                                                   -32.74%             -32.34%               0.40%
# Franklin County                                                -31.59%             -29.00%               2.59%
# Fulton County                                                  -30.69%             -36.74%              -6.05%
# Genesee County                                                 -32.20%             -38.30%              -6.11%
# Greene County                                                  -30.45%             -40.27%              -9.83%
# Hamilton County                                                -31.05%             -35.73%              -4.68%
# Lewis County                                                   -30.09%             -33.58%              -3.49%
# Montgomery County                                              -32.16%             -41.31%              -9.14%
# Otsego County                                                  -33.72%             -36.72%              -2.99%
# St. Lawrence County                                            -30.51%             -40.43%              -9.92%
# Schuyler County                                                -31.39%             -37.61%              -6.22%
# Seneca County                                                  -35.15%             -35.13%               0.03%
# Steuben County                                                 -31.53%             -35.90%              -4.37%
# Sullivan County                                                -33.13%             -34.94%              -1.81%
# Wyoming County                                                 -29.63%             -35.08%              -5.45%
# Albany-Schenectady-Troy Metro Area                             -30.87%             -41.92%             -11.05%
# Binghamton Metro Area                                          -32.04%             -51.31%             -19.26%
# Buffalo-Niagara Falls Metro Area                               -32.80%             -68.82%             -36.02%
# Dutchess-Putnam Metropolitan Division                          -32.21%             -41.41%              -9.20%
# Elmira Metro Area                                              -31.22%             -35.30%              -4.07%
# Glens Falls Metro Area                                         -32.16%             -29.98%               2.18%
# Ithaca Metro Area                                              -31.13%             -39.39%              -8.25%
# Kingston Metro Area                                            -32.82%             -34.18%              -1.36%
# Nassau-Suffolk Metropolitan Division                           -33.21%             -36.80%              -3.59%
# Rochester Metro Area                                           -31.68%             -55.84%             -24.17%
# Syracuse Metro Area                                            -31.43%             -41.07%              -9.64%
# Utica-Rome Metro Area                                          -31.47%             -42.72%             -11.25%
# Watertown-Fort Drum Metro Area                                 -31.60%             -42.18%             -10.57%
# New York City                                                  -33.47%             -38.08%              -4.62%
# Orange-Rockland-Westchester Metro Area                         -33.00%             -40.05%              -7.05%

# %%
import csv, operator

f_st_change = "st_change.csv"
f_st_ch = open(f_st_change, 'r')

f_dol = "DOL_geog_areas.csv"
f_areas = open(f_dol, 'r')

JurisCount = 0
reader_stc = csv.reader(f_st_ch)
reader_dol = csv.reader(f_areas)
ST_changeHist = {}

n_stc = 0

for row_c in reader_stc:
#    print(n_stc, type(row_c[0]), type(row_c[1]), type(row_c[2]))
    print(n, *row_c)
    n_stc += 1
# Out:
# 0 Jurisdiction Yr1 Yr2
# 1 NY STATE 1672222422.56 734206082.76
# 2 MCTD 121692620.3 47859808.76
# 3 ALBANY 25677639.08 13147845.04
# 4 ALLEGANY 1395069.89 896908.41
# 5 BROOME 11775309.88 7213391.36
# 6 CATTARAUGUS 3565879.72 2176182.92
# 7 CAYUGA 3429950.64 2104314.68
# 8 CHAUTAUQUA 6716551.16 4463443.2
# 9 CHEMUNG 5261823.88 3246488.08
# 10 CHENANGO 1343271.92 869139.56
# 11 CLINTON 4635167.08 2811511.96
# 12 COLUMBIA 3176966.56 1932692.0
# 13 CORTLAND 2343189.88 1440646.32
# 14 DELAWARE 1306656.08 884947.16
# 15 DUTCHESS 17631102.79 10508226.82
# 16 ERIE 81947362.81 48117913.82
# 17 ESSEX 2596944.92 1550961.04
# 18 FRANKLIN 1498528.88 1013887.32
# 19 FULTON 2254968.88 1601003.04
# 20 GENESEE 3543316.68 2241558.56
# 21 GREENE 2599582.08 1603872.0
# 22 HAMILTON 289841.16 173113.88
# 23 HERKIMER 2816719.67 1810412.32
# 24 JEFFERSON 7347141.64 4840091.08
# 25 LEWIS 839431.52 485385.6
# 26 LIVINGSTON 2952825.16 1961233.08
# 27 MADISON 2659893.76 1693110.92
# 28 MONROE 47447962.84 28261854.56
# 29 MONTGOMERY 2097357.0 1367058.52
# 30 NASSAU 120718334.42 70853850.9
# 31 NIAGARA 12214070.0 7530733.32
# 32 NY CITY 1042285226.85 324826133.4
# 33 ONEIDA 12178556.4 7540886.32
# 34 ONONDAGA 33049107.36 18502383.96
# 35 ONTARIO 7463357.02 4377085.65
# 36 ORANGE 21905306.25 13381335.3
# 37 ORLEANS 1186786.88 893868.16
# 38 OSWEGO 3107149.48 2149199.0
# 39 OTSEGO 3566457.84 1905943.04
# 40 PUTNAM 4262185.08 2697140.72
# 41 RENSSELAER 7806360.8 4535873.16
# 42 ROCKLAND 17231289.2 9471640.56
# 43 SARATOGA 12950177.79 7429034.88
# 44 SCHENECTADY 7678289.04 4784699.24
# 45 SCHOHARIE 987354.48 658829.64
# 46 SCHUYLER 894295.2 611459.72
# 47 SENECA 1599437.44 997908.16
# 48 ST LAWRENCE 4021318.44 2608802.04
# 49 STEUBEN 4151121.52 2472897.72
# 50 SUFFOLK 129000688.94 82685005.66
# 51 SULLIVAN 2784410.28 1873428.92
# 52 TIOGA 1365585.0 888441.72
# 53 TOMPKINS 6316928.88 3035799.16
# 54 ULSTER 11270859.76 6831807.04
# 55 WARREN 6103127.52 4017135.45
# 56 WASHINGTON 1002364.83 690434.07
# 57 WAYNE 2913928.96 2051743.12
# 58 WESTCHESTER 72455917.72 39575666.2
# 59 WYOMING 1475010.36 1020631.84
# 60 YATES 778477.28 505360.72
